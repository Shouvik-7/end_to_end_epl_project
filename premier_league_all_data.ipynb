# %% [markdown]
# https://www.kaggle.com/code/lorenzodifolco/premier-league-2000-2018-analysis

# %% [markdown]
# Use SQL to find pts, gd, gs, gc, wins, losses, draws

# %%
import pandas as pd 
import xgboost as xgb 
from sklearn.linear_model import LogisticRegression 
from sklearn.svm import SVC 
import matplotlib.pyplot as plt

# %%
import os

# %%
df = pd.read_csv('2324.csv')

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'HTHG', 'HTAG',
#        ...
#        'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH',
#        'MaxCAHA', 'AvgCAHH', 'AvgCAHA'],
#       dtype='object', length=106)

# %%
field_names = ['Div','Date' ,'Time' ,'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY','AY', 'HR', 'AR']

# %%
df[field_names]
# Out:
#     Div        Date   Time          HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E0  11/08/2023  20:00           Burnley       Man City     0     3   A
# 1    E0  12/08/2023  12:30           Arsenal  Nott'm Forest     2     1   H
# 2    E0  12/08/2023  15:00       Bournemouth       West Ham     1     1   D
# 3    E0  12/08/2023  15:00          Brighton          Luton     4     1   H
# 4    E0  12/08/2023  15:00           Everton         Fulham     0     1   A
# ..   ..         ...    ...               ...            ...   ...   ...  ..
# 375  E0  19/05/2024  16:00    Crystal Palace    Aston Villa     5     0   H
# 376  E0  19/05/2024  16:00         Liverpool         Wolves     2     0   H
# 377  E0  19/05/2024  16:00             Luton         Fulham     2     4   A
# 378  E0  19/05/2024  16:00          Man City       West Ham     3     1   H
# 379  E0  19/05/2024  16:00  Sheffield United      Tottenham     0     3   A
#
#      HTHG  HTAG  ... HST AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0       0     2  ...   1   8  11   8   6   5   0   0   1   0
# 1       2     0  ...   7   2  12  12   8   3   2   2   0   0
# 2       0     0  ...   5   3   9  14  10   4   1   4   0   0
# 3       1     0  ...  12   3  11  12   6   7   2   2   0   0
# 4       0     0  ...   9   2  12   6  10   4   0   2   0   0
# ..    ...   ...  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 375     2     0  ...   9   2  10   8   2   4   1   4   0   0
# 376     2     0  ...  14   3  14  11  10   2   1   1   0   1
# 377     1     2  ...   6   7  15  20   4   4   5   4   0   0
# 378     2     1  ...  12   2   3  12  11   2   0   1   0   0
# 379     0     1  ...   1   9  11   9   2   6   2   0   0   0
#
# [380 rows x 24 columns]

# %%
os.listdir()
# Out:
# ['1617.csv',
#  '1718.csv',
#  '1819.csv',
#  '1920.csv',
#  '2021.csv',
#  '2122.csv',
#  '2223.csv',
#  '2324.csv',
#  'premier_league copy.ipynb',
#  'premier_league.ipynb']

# %%
import pandas as pd 
  
# merging two csv files 
df = pd.concat( 
    map(pd.read_csv, ['1617.csv',
 '1718.csv',
 '1819.csv',
 '1920.csv',
 '2021.csv',
 '2122.csv',
 '2223.csv',
 '2324.csv']), ignore_index=True) 
print(df)
# Out:
#      Div        Date          HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     E0    13/08/16           Burnley      Swansea     0     1   A     0
# 1     E0    13/08/16    Crystal Palace    West Brom     0     1   A     0
# 2     E0    13/08/16           Everton    Tottenham     1     1   D     1
# 3     E0    13/08/16              Hull    Leicester     2     1   H     1
# 4     E0    13/08/16          Man City   Sunderland     2     1   H     1
# ...   ..         ...               ...          ...   ...   ...  ..   ...
# 3035  E0  19/05/2024    Crystal Palace  Aston Villa     5     0   H     2
# 3036  E0  19/05/2024         Liverpool       Wolves     2     0   H     2
# 3037  E0  19/05/2024             Luton       Fulham     2     4   A     1
# 3038  E0  19/05/2024          Man City     West Ham     3     1   H     2
# 3039  E0  19/05/2024  Sheffield United    Tottenham     0     3   A     0
#
#       HTAG HTR  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0        0   D  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 1        0   D  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 2        0   H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 3        0   H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 4        0   H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# ...    ...  ..  ...      ...   ...       ...       ...    ...    ...      ...
# 3035     0   H  ...     2.78 -0.75      1.73      2.08   1.78   2.16     1.93
# 3036     0   H  ...     5.17 -2.75      2.07      1.86   2.04   1.85     2.10
# 3037     2   A  ...     2.69  0.25      2.00      1.93   1.99   1.93     2.02
# 3038     1   H  ...     4.82 -3.00      2.03      1.90   1.99   1.90     2.05
# 3039     1   A  ...     3.81  1.50      2.06      1.87   2.05   1.88     2.08
#
#       MaxCAHA  AvgCAHH  AvgCAHA
# 0         NaN      NaN      NaN
# 1         NaN      NaN      NaN
# 2         NaN      NaN      NaN
# 3         NaN      NaN      NaN
# 4         NaN      NaN      NaN
# ...       ...      ...      ...
# 3035     2.21     1.81     2.05
# 3036     1.89     2.04     1.82
# 3037     1.94     1.96     1.91
# 3038     1.99     1.96     1.91
# 3039     1.89     2.01     1.86
#
# [3040 rows x 127 columns]

# %%
df
# Out:
#      Div        Date          HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     E0    13/08/16           Burnley      Swansea     0     1   A     0
# 1     E0    13/08/16    Crystal Palace    West Brom     0     1   A     0
# 2     E0    13/08/16           Everton    Tottenham     1     1   D     1
# 3     E0    13/08/16              Hull    Leicester     2     1   H     1
# 4     E0    13/08/16          Man City   Sunderland     2     1   H     1
# ...   ..         ...               ...          ...   ...   ...  ..   ...
# 3035  E0  19/05/2024    Crystal Palace  Aston Villa     5     0   H     2
# 3036  E0  19/05/2024         Liverpool       Wolves     2     0   H     2
# 3037  E0  19/05/2024             Luton       Fulham     2     4   A     1
# 3038  E0  19/05/2024          Man City     West Ham     3     1   H     2
# 3039  E0  19/05/2024  Sheffield United    Tottenham     0     3   A     0
#
#       HTAG HTR  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0        0   D  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 1        0   D  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 2        0   H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 3        0   H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 4        0   H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# ...    ...  ..  ...      ...   ...       ...       ...    ...    ...      ...
# 3035     0   H  ...     2.78 -0.75      1.73      2.08   1.78   2.16     1.93
# 3036     0   H  ...     5.17 -2.75      2.07      1.86   2.04   1.85     2.10
# 3037     2   A  ...     2.69  0.25      2.00      1.93   1.99   1.93     2.02
# 3038     1   H  ...     4.82 -3.00      2.03      1.90   1.99   1.90     2.05
# 3039     1   A  ...     3.81  1.50      2.06      1.87   2.05   1.88     2.08
#
#       MaxCAHA  AvgCAHH  AvgCAHA
# 0         NaN      NaN      NaN
# 1         NaN      NaN      NaN
# 2         NaN      NaN      NaN
# 3         NaN      NaN      NaN
# 4         NaN      NaN      NaN
# ...       ...      ...      ...
# 3035     2.21     1.81     2.05
# 3036     1.89     2.04     1.82
# 3037     1.94     1.96     1.91
# 3038     1.99     1.96     1.91
# 3039     1.89     2.01     1.86
#
# [3040 rows x 127 columns]

# %%
df.head()
# Out:
#   Div      Date        HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  13/08/16         Burnley     Swansea     0     1   A     0     0   D
# 1  E0  13/08/16  Crystal Palace   West Brom     0     1   A     0     0   D
# 2  E0  13/08/16         Everton   Tottenham     1     1   D     1     0   H
# 3  E0  13/08/16            Hull   Leicester     2     1   H     1     0   H
# 4  E0  13/08/16        Man City  Sunderland     2     1   H     1     0   H
#
#    ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 1  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 2  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 3  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 4  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
#
#    AvgCAHH  AvgCAHA
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
#
# [5 rows x 127 columns]

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR',
#        ...
#        'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH',
#        'MaxCAHA', 'AvgCAHH', 'AvgCAHA'],
#       dtype='object', length=127)

# %%
df.iloc[:5,:]
# Out:
#   Div      Date        HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  13/08/16         Burnley     Swansea     0     1   A     0     0   D
# 1  E0  13/08/16  Crystal Palace   West Brom     0     1   A     0     0   D
# 2  E0  13/08/16         Everton   Tottenham     1     1   D     1     0   H
# 3  E0  13/08/16            Hull   Leicester     2     1   H     1     0   H
# 4  E0  13/08/16        Man City  Sunderland     2     1   H     1     0   H
#
#    ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 1  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 2  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 3  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 4  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
#
#    AvgCAHH  AvgCAHA
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
#
# [5 rows x 127 columns]

# %%
df = df.iloc[:,:24]

# %%
# Description of Dataset

# Key to results data:

# Div = League Division
# Date = Match Date (dd/mm/yy)
# Time = Time of match kick-off
# HomeTeam = Home Team
# Away team = Away Team
# FTHG and HG = Full Time Home Team Goals
# FTAG and AG = Full-Time Away Team Goals
# FTR and Res = Full-Time Result (H=Home Win, D=Draw, A=Away Win)
# HTHG = Half Time Home Team Goals
# HTAG = Half Time Away Team Goals
# HTR = Half Time Result (H=Home Win, D=Draw, A=Away Win)
# Match Statistics (where available)

# Attendance = Crowd Attendance
# Referee = Match Referee
# HS = Home Team Shots
# AS = Away Team Shots
# HST = Home Team Shots on Target
# AST = Away Team Shots on Target
# HHW = Home Team Hit Woodwork
# AHW = Away Team Hit Woodwork
# HC = Home Team Corners
# AC = Away Team Corners
# HF = Home Team Fouls Committed
# AF = Away Team Fouls Committed
# HFKC = Home Team Free Kicks Conceded
# AFKC = Away Team Free Kicks Conceded
# HO = Home Team Offsides
# AO = Away Team Offsides
# HY = Home Team Yellow Cards
# AY = Away Team Yellow Cards *HR = Home Team Red Cards AR = Away Team Red Cards HBP = Home Team Bookings Points (10 = yellow, 25 = red) ABP = Away Team Bookings Points (10 = yellow, 25 = red)

# %%
print(df.columns.values)
# Out:
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3040 entries, 0 to 3039
# Data columns (total 24 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       3040 non-null   object
#  1   Date      3040 non-null   object
#  2   HomeTeam  3040 non-null   object
#  3   AwayTeam  3040 non-null   object
#  4   FTHG      3040 non-null   int64
#  5   FTAG      3040 non-null   int64
#  6   FTR       3040 non-null   object
#  7   HTHG      3040 non-null   int64
#  8   HTAG      3040 non-null   int64
#  9   HTR       3040 non-null   object
#  10  Referee   3040 non-null   object
#  11  HS        3040 non-null   int64
#  12  AS        3040 non-null   int64
#  13  HST       3040 non-null   int64
#  14  AST       3040 non-null   int64
#  15  HF        3040 non-null   int64
#  16  AF        3040 non-null   int64
#  17  HC        3040 non-null   int64
#  18  AC        3040 non-null   int64
#  19  HY        3040 non-null   int64
#  20  AY        3040 non-null   int64
#  21  HR        3040 non-null   int64
#  22  AR        3040 non-null   int64
#  23  B365H     3040 non-null   float64
# dtypes: float64(1), int64(16), object(7)
# memory usage: 570.1+ KB

# %%
df.describe()
# Out:
#               FTHG         FTAG         HTHG         HTAG           HS  \
# count  3040.000000  3040.000000  3040.000000  3040.000000  3040.000000
# mean      1.564145     1.269079     0.691447     0.566776    13.884868
# std       1.334668     1.223588     0.851721     0.778209     5.784370
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000     0.000000    10.000000
# 50%       1.000000     1.000000     0.000000     0.000000    13.000000
# 75%       2.000000     2.000000     1.000000     1.000000    17.000000
# max       9.000000     9.000000     5.000000     5.000000    37.000000
#
#                 AS          HST          AST           HF           AF  \
# count  3040.000000  3040.000000  3040.000000  3040.000000  3040.000000
# mean     11.434868     4.793092     4.012171    10.567434    10.801974
# std       5.067206     2.676409     2.393129     3.424654     3.586508
# min       0.000000     0.000000     0.000000     0.000000     1.000000
# 25%       8.000000     3.000000     2.000000     8.000000     8.000000
# 50%      11.000000     4.000000     4.000000    10.000000    11.000000
# 75%      15.000000     6.000000     5.000000    13.000000    13.000000
# max      31.000000    17.000000    15.000000    24.000000    26.000000
#
#                 HC           AC           HY           AY           HR  \
# count  3040.000000  3040.000000  3040.000000  3040.000000  3040.000000
# mean      5.727961     4.675329     1.624342     1.784211     0.052632
# std       3.081648     2.771580     1.257423     1.287605     0.232006
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     3.000000     1.000000     1.000000     0.000000
# 50%       5.000000     4.000000     1.000000     2.000000     0.000000
# 75%       8.000000     6.000000     2.000000     3.000000     0.000000
# max      19.000000    19.000000     6.000000     7.000000     2.000000
#
#                 AR        B365H
# count  3040.000000  3040.000000
# mean      0.061184     3.024885
# std       0.246475     2.391681
# min       0.000000     1.060000
# 25%       0.000000     1.650000
# 50%       0.000000     2.250000
# 75%       0.000000     3.300000
# max       2.000000    23.000000

# %%
n_matches = df.shape[0]
n_features = df.shape[1] - 1 
n_homewins = len(df[df.FTR == 'H'])

win_rate = (float(n_homewins)/(n_matches))*100 
print(win_rate)
# Out:
# 45.36184210526316

# %%
# from pandas.plotting import scatter_matrix
# scatter_matrix(df)

# %%
df.head()
# Out:
#   Div      Date        HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  13/08/16         Burnley     Swansea     0     1   A     0     0   D
# 1  E0  13/08/16  Crystal Palace   West Brom     0     1   A     0     0   D
# 2  E0  13/08/16         Everton   Tottenham     1     1   D     1     0   H
# 3  E0  13/08/16            Hull   Leicester     2     1   H     1     0   H
# 4  E0  13/08/16        Man City  Sunderland     2     1   H     1     0   H
#
#    ... AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H
# 0  ...   9  10  14   7   4   3   2   0   0   2.40
# 1  ...   3  12  15   3   6   2   2   0   0   2.00
# 2  ...   4  10  14   5   6   0   0   0   0   3.20
# 3  ...   5   8  17   5   3   2   2   0   0   4.50
# 4  ...   3  11  14   9   6   1   2   0   0   1.25
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (3040, 24)

# %%
df['HomeTeam'].value_counts()
# Out:
# HomeTeam
# Crystal Palace      152
# Liverpool           152
# Everton             152
# Man City            152
# Arsenal             152
# Man United          152
# Tottenham           152
# Chelsea             152
# West Ham            152
# Burnley             133
# Brighton            133
# Leicester           133
# Southampton         133
# Newcastle           133
# Bournemouth         114
# Wolves              114
# Watford              95
# Aston Villa          95
# Fulham               76
# Brentford            57
# Sheffield United     57
# West Brom            57
# Leeds                57
# Swansea              38
# Stoke                38
# Norwich              38
# Huddersfield         38
# Nott'm Forest        38
# Middlesbrough        19
# Hull                 19
# Sunderland           19
# Cardiff              19
# Luton                19
# Name: count, dtype: int64

# %%
df['AwayTeam'].value_counts()
# Out:
# AwayTeam
# Tottenham           152
# Chelsea             152
# Man United          152
# Liverpool           152
# Everton             152
# Crystal Palace      152
# Man City            152
# Arsenal             152
# West Ham            152
# Brighton            133
# Leicester           133
# Southampton         133
# Burnley             133
# Newcastle           133
# Bournemouth         114
# Wolves              114
# Watford              95
# Aston Villa          95
# Fulham               76
# Brentford            57
# West Brom            57
# Sheffield United     57
# Leeds                57
# Swansea              38
# Stoke                38
# Nott'm Forest        38
# Norwich              38
# Huddersfield         38
# Sunderland           19
# Hull                 19
# Middlesbrough        19
# Cardiff              19
# Luton                19
# Name: count, dtype: int64

# %% [markdown]
# # Datetime

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
# Out:
# C:\Users\shouv\AppData\Local\Temp\ipykernel_13724\4183834281.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# %%
df["Day_code"] = df['Date'].dt.dayofweek

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['homecode'] = le.fit_transform(df['HomeTeam'])
df['awaycode'] = le.transform(df['AwayTeam'])
df.head()
# Out:
#   Div       Date        HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0 2016-08-13         Burnley     Swansea     0     1   A     0     0   D
# 1  E0 2016-08-13  Crystal Palace   West Brom     0     1   A     0     0   D
# 2  E0 2016-08-13         Everton   Tottenham     1     1   D     1     0   H
# 3  E0 2016-08-13            Hull   Leicester     2     1   H     1     0   H
# 4  E0 2016-08-13        Man City  Sunderland     2     1   H     1     0   H
#
#    ... HC  AC  HY  AY  HR  AR  B365H  Day_code  homecode  awaycode
# 0  ...  7   4   3   2   0   0   2.40         5         5        27
# 1  ...  3   6   2   2   0   0   2.00         5         8        30
# 2  ...  5   6   0   0   0   0   3.20         5         9        28
# 3  ...  5   3   2   2   0   0   4.50         5        12        14
# 4  ...  9   6   1   2   0   0   1.25         5        17        26
#
# [5 rows x 27 columns]

# %%
le.inverse_transform(list(range(0,20)))
# Out:
# array(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford', 'Brighton',
#        'Burnley', 'Cardiff', 'Chelsea', 'Crystal Palace', 'Everton',
#        'Fulham', 'Huddersfield', 'Hull', 'Leeds', 'Leicester',
#        'Liverpool', 'Luton', 'Man City', 'Man United', 'Middlesbrough'],
#       dtype=object)

# %%
# Linear model cannot makeout the teams number is not ordinal 
from sklearn.ensemble import RandomForestClassifier 
rf = RandomForestClassifier(n_estimators=50, min_samples_leaf=4, random_state=1)

# %%
train = df[:-100]
test = df[-1000:]

# %%
features = ["Day_code", "homecode", "awaycode"]

# %%
rf.fit(train[features], train['FTR'])
# Out:
# RandomForestClassifier(min_samples_leaf=4, n_estimators=50, random_state=1)

# %%
rf.predict(test[features])
# Out:
# array(['H', 'D', 'A', 'A', 'D', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H',
#        'H', 'A', 'H', 'H', 'H', 'A', 'H', 'D', 'D', 'H', 'D', 'H', 'A',
#        'A', 'H', 'H', 'H', 'A', 'H', 'H', 'A', 'H', 'D', 'H', 'D', 'H',
#        'H', 'H', 'A', 'H', 'A', 'D', 'A', 'A', 'A', 'H', 'D', 'H', 'H',
#        'H', 'D', 'H', 'D', 'A', 'H', 'A', 'H', 'H', 'A', 'H', 'A', 'H',
#        'A', 'D', 'A', 'H', 'A', 'H', 'D', 'H', 'D', 'H', 'H', 'H', 'A',
#        'H', 'D', 'H', 'H', 'H', 'A', 'H', 'D', 'H', 'A', 'A', 'A', 'H',
#        'H', 'H', 'H', 'D', 'H', 'A', 'D', 'A', 'H', 'A', 'H', 'A', 'H',
#        'H', 'A', 'H', 'H', 'H', 'A', 'H', 'H', 'H', 'D', 'A', 'H', 'A',
#        'H', 'H', 'A', 'H', 'A', 'A', 'H', 'A', 'H', 'H', 'A', 'A', 'H',
 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'A',
#        'A', 'H', 'H', 'A', 'H', 'H', 'A', 'D', 'A', 'H', 'A', 'H', 'H',
#        'H', 'A', 'A', 'H', 'H', 'H', 'H', 'H', 'H', 'A', 'H', 'H', 'H',
#        'A', 'H', 'H', 'H', 'A', 'H', 'A', 'A', 'A', 'H', 'H', 'A', 'H',
#        'H', 'H', 'H', 'A', 'H', 'H', 'H', 'D', 'H', 'H', 'H', 'A', 'H',
#        'H', 'A', 'A', 'H', 'H', 'H', 'H', 'A', 'A', 'A', 'H', 'A', 'A',
#        'D', 'H', 'H', 'H', 'H', 'D', 'H', 'A', 'H', 'H', 'H', 'A'],
#       dtype=object)

# %%
test['FTR']
# Out:
# 2040    H
# 2041    D
# 2042    A
# 2043    A
# 2044    D
#        ..
# 3035    H
# 3036    H
# 3037    A
# 3038    H
# 3039    A
# Name: FTR, Length: 1000, dtype: object

# %%
from sklearn.metrics import classification_report
print(classification_report(test['FTR'], rf.predict(test[features])))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.62      0.62      0.62       316
#            D       0.70      0.33      0.45       218
#            H       0.67      0.84      0.75       466
#
#     accuracy                           0.66      1000
#    macro avg       0.66      0.60      0.61      1000
# weighted avg       0.66      0.66      0.64      1000

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(test['FTR'], rf.predict(test[features]))
# Out:
# array([[196,  21,  99],
#        [ 54,  73,  91],
#        [ 66,  10, 390]])

# %% [markdown]
# # Feature engineering

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("Date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ['FTHG','FTAG','HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY','AY', 'HR', 'AR']
new_cols_h = [f"{c}_rolling_ht" for c in cols]
new_cols_a = [f"{c}_rolling_at" for c in cols]

# %%
matches_rolling_h = df.groupby("HomeTeam").apply(lambda x: rolling_averages(x, cols, new_cols_h))
matches_rolling_h = matches_rolling_h.droplevel('HomeTeam')
# Out:
# C:\Users\shouv\AppData\Local\Temp\ipykernel_13724\553221324.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling_h = df.groupby("HomeTeam").apply(lambda x: rolling_averages(x, cols, new_cols_h))

# %%
matches_rolling_h = matches_rolling_h.groupby("AwayTeam").apply(lambda x: rolling_averages(x, cols, new_cols_a))
matches_rolling_h = matches_rolling_h.droplevel('AwayTeam')
# Out:
# C:\Users\shouv\AppData\Local\Temp\ipykernel_13724\3882690442.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling_h = matches_rolling_h.groupby("AwayTeam").apply(lambda x: rolling_averages(x, cols, new_cols_a))

# %%
matches_rolling_h.head()
# Out:
#     Div       Date     HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  ...  \
# 136  E0 2016-12-03     West Ham  Arsenal     1     5   A     0     1   A  ...
# 151  E0 2016-12-13      Everton  Arsenal     2     1   H     1     1   D  ...
# 167  E0 2016-12-18     Man City  Arsenal     2     1   H     0     1   A  ...
# 196  E0 2017-01-03  Bournemouth  Arsenal     3     3   D     2     0   H  ...
# 204  E0 2017-01-14      Swansea  Arsenal     0     4   A     0     1   A  ...
#
#     HST_rolling_at  AST_rolling_at  HF_rolling_at  AF_rolling_at  \
# 136       2.333333        3.666667       8.333333       9.000000
# 151       3.000000        6.000000      11.000000      11.666667
# 167       4.000000        4.666667      11.333333      10.666667
# 196       4.000000        4.666667       9.666667      11.333333
# 204       5.000000        2.666667       9.666667      11.666667
#
#      HC_rolling_at  AC_rolling_at  HY_rolling_at  AY_rolling_at  \
# 136       4.000000       6.000000       2.333333       2.000000
# 151       4.333333       4.666667       3.333333       3.000000
# 167       7.000000       3.000000       2.333333       2.333333
# 196       6.333333       2.000000       2.666667       2.000000
# 204       6.666667       3.666667       2.666667       2.000000
#
#      HR_rolling_at  AR_rolling_at
# 136       0.000000            0.0
# 151       0.000000            0.0
# 167       0.333333            0.0
# 196       0.333333            0.0
# 204       0.666667            0.0
#
# [5 rows x 55 columns]

# %%
matches = matches_rolling_h.sort_values(['Date'])

# %% [markdown]
# # Model Building

# %%
features = ["Day_code", "homecode", "awaycode"]  
feat_set = features + new_cols_h + new_cols_a

# %%
# Linear model cannot makeout the teams number is not ordinal 
from sklearn.ensemble import RandomForestClassifier 
rf = RandomForestClassifier(n_estimators=50, min_samples_leaf=4, random_state=1)

# %%
train = matches[:-100]
test = matches[-100:]

# %%
rf.fit(train[feat_set], train['FTR'])
# Out:
# RandomForestClassifier(min_samples_leaf=4, n_estimators=50, random_state=1)

# %%
y_pred = list(rf.predict(test[feat_set]))

# %%
from sklearn.metrics import classification_report
print(classification_report(test['FTR'], rf.predict(test[feat_set])))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.46      0.41      0.44        29
#            D       0.00      0.00      0.00        24
#            H       0.55      0.87      0.68        47
#
#     accuracy                           0.53       100
#    macro avg       0.34      0.43      0.37       100
# weighted avg       0.39      0.53      0.45       100
# c:\Users\shouv\anaconda3\envs\EPL_GCP\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\shouv\anaconda3\envs\EPL_GCP\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\shouv\anaconda3\envs\EPL_GCP\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(list(test['FTR']), y_pred)
# Out:
# array([[12,  0, 17],
#        [ 8,  0, 16],
#        [ 6,  0, 41]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(matches, matches['FTR'], test_size=0.33, random_state=42)

# %%
rf.fit(X_train[feat_set], y_train)
# Out:
# RandomForestClassifier(min_samples_leaf=4, n_estimators=50, random_state=1)

# %%
y_pred = list(rf.predict(X_test[feat_set]))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, rf.predict(X_test[feat_set])))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.43      0.47      0.45       288
#            D       0.30      0.01      0.03       221
#            H       0.54      0.77      0.63       429
#
#     accuracy                           0.50       938
#    macro avg       0.42      0.42      0.37       938
# weighted avg       0.45      0.50      0.43       938
